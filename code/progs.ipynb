# %%
a, i, di = int(input()), 0, dict()
for i in range(a):
    c = int(input())
    if c not in di:
        di[c] = f(c)
        print(di[c])
    else:
        print(di[c])

# %%
import requests
with open('test.txt') as inf:
    url = str(inf.readline().strip())
r, cnt = requests.get(url), 0
print(r.text)
# cnt = len(r.text.splitlines())
for i in r.text:
    if i == '\n':
        cnt += 1
print(cnt)
# Out:
# "I rarely watch the 'parlor walls' or go to races or Fun Parks. So I've lots of time for crazy thoughts, I guess. Have you seen the two hundred-foot-long billboards in the country beyond town ? Did you know that once billboards were only twenty feet long? But cars started rushing by so quickly they had to stretch the advertising out so it would last."
#
# "I didn't know that!" Montag laughed abruptly.
#
# "Bet I know something else you don't. There's dew on the grass in the morning."
#
# He suddenly couldn't remember if he had known this or not, and it made him quite irritable.
#
# "And if you look" -- she nodded at the sky -- "there's a man in the moon."
#
# He hadn't looked for a long time.
#
# They walked the rest of the way in silence, hers thoughtful, his a kind of clenching and uncomfortable silence in which he shot her accusing glances.  When they reached her house all its lights were blazing.
#
# "What's going on?" Montag had rarely seen that many house lights.
#
# ...

# %%
import requests
with open('test.txt') as inf:
    url = str(inf.readline().strip())
r = requests.get(url)
while True:
    if 'We' in r.text:
        print(r.text)
        break
    print(r.text)
    r = requests.get('https://stepic.org/media/attachments/course67/3.6.3/' + r.text)
# Out:
# 213837.txt
# 396639.txt
# 835329.txt
# 344063.txt
# 194307.txt
# 195211.txt
# 769171.txt
# 153554.txt
# 680916.txt
# 335636.txt
# 935728.txt
# 081303.txt
# 792633.txt
# 668368.txt
# 647731.txt
# 904392.txt
# 684563.txt
# 997337.txt
# 329467.txt
# 366219.txt
# 730037.txt
# 310230.txt
# 104249.txt
# 382504.txt
# 433681.txt
# 507359.txt
# 293649.txt
# 011641.txt
# 717942.txt
# 258080.txt
# 569395.txt
# 756825.txt
# 921388.txt
# 437007.txt
# 004090.txt
# 362705.txt
# 145282.txt
# 990216.txt
# 645783.txt
# 451262.txt
# 193295.txt
# 777343.txt
# 324603.txt
# 888934.txt
# 138655.txt
# 818396.txt
# 290594.txt
# 478003.txt
# 276687.txt
# 703763.txt
# 712469.txt
# 064418.txt
# 246033.txt
# 356768.txt
# 504290.txt
# 629914.txt
# 062456.txt
# 658472.txt
# 037659.txt
# 351978.txt
# 523822.txt
# 653493.txt
# 859227.txt
# 878358.txt
# 944504.txt
# 457602.txt
# 548571.txt
# 090976.txt
# 965991.txt
# 138128.txt
# 255843.txt
# 797598.txt
# 640003.txt
# 789435.txt
# 181382.txt
# 590526.txt
# ...

# %%
b, di, a = [], {}, int(input())
b = [input().split(';') for i in range(a)] 
#with open('test.txt') as inf:
    #p = inf.read().splitlines()
    # b = [i.split(';') for i in p]
for val in b:
    if val[0] in di:
        di[val[0]][0] += 1
    else:
        di[val[0]] = [1, 0, 0]
    if val[2] in di:
        di[val[2]][0] += 1
    else:
        di[val[2]] = [1, 0, 0]
    if val[1] > val[3]:
        di[val[0]][1] += 1
    elif val[1] < val[3]:
        di[val[2]][1] += 1
    else:
        di[val[0]][2] += 1
        di[val[2]][2] += 1
for val in di:
    print(val+':'+str(di[val][0]),str(di[val][1]),str(di[val][2]),str(di[val][0]-di[val][1]-di[val][2]),str(di[val][1]*3+di[val][2]),end='\n')
# Out:
# ЦСКА:2 0 1 1 1
# Зенит:2 2 0 0 6
# Спартак:2 0 1 1 1

# %%
Зенит;3;Спартак;1
Спартак;1;ЦСКА;1
ЦСКА;0;Зенит;2

# %%
def update_dictionary(di, k, v):
    if k in di:
        di[k] += [v]
    elif k*2 in di:
        di[k*2] += [v]
    else:
        di[k*2] = [v]

# %%
k, s = int(input()), set()
b = [input().lower() for i in range(k)] 
k2 = int(input())
b2 = set([val for i in range(k2) for val in input().lower().split()])
for val in b2:
    if val not in b:
        print(val)

# %%
"""k, s = int(input()), set()
b = [input().lower() for i in range(k)] 
k2 = int(input())
b2 = set([input().lower().split() for i in range(k2)])"""
with open('test.txt') as inf:
    b = inf.read().lower().splitlines()
with open('test2.txt') as inf2:
    b2 = set([b2 for line in inf2 for b2 in line.split()])
for val in b2:
    if val not in b:
        print(val)
# Out:
# ['a', 'bb', 'ccc']
#
# {'a', 'bb', 'c', 'aab', 'aba', 'ccc', 'aaa'}
#
# c
# aab
# aba
# aaa

# %%
import numpy as np
a = np.eye(3, 4, 0)
b = np.eye(3, 4, 1)
mat = 2*a + b
print(mat.reshape((12,1)))
# Out:
# [[2.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]
#  [2.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]
#  [2.]
#  [1.]]

# %%
import numpy as np

x_shape = tuple(map(int, input().split()))
X = np.fromiter(map(int, input().split()), np.int).reshape(x_shape)
y_shape = tuple(map(int, input().split()))
Y = np.fromiter(map(int, input().split()), np.int).reshape(y_shape)

try:
    print(X.dot(Y.T))
except:
    print("matrix shapes do not match")

# here goes your solution; X and Y are already defined!
# Out:
# 2 3
# 5 9 9 10 8 9
# 3 4
# 6 11 3 5 4 5 3 2 5 8 2 2
# matrix shapes do not match

# %%
2 3
5 9 9 10 8 9
3 4
6 11 3 5 4 5 3 2 5 8 2 2
